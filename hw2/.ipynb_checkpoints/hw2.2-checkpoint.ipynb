# %% [markdown]
# ### ДЗ 2.2

# %%
# %load_ext pycodestyle_magic
# %flake8_on
# Out:
# The pycodestyle_magic extension is already loaded. To reload it, use:
#   %reload_ext pycodestyle_magic

# %% [markdown]
# Откроем JSON, который сделан пайморфом, так как его не придётся преобразовывать.

# %%
import json

with open('list_of_parsing.json', encoding='utf-8') as f:
    list_of_parsing = json.load(f)

# %% [markdown]
# #### 1. Перевести разметку в датафрейм, подобный тому, что был на семинаре
# Выведем первые несколько строк:

# %%
import pandas
import matplotlib.pyplot as pyplot

dataframe = pandas.DataFrame(list_of_parsing)
dataframe[:50]
# Out:
#            word   pos animacy aspect  case gender involvement  mood number  \
# 0          метр  NOUN    inan   None  gent   masc        None  None   sing
# 1        правда  PRCL    None   None  None   None        None  None   None
# 2          1989  None    None   None  None   None        None  None   None
# 3           ocr  None    None   None  None   None        None  None   None
# 4           amp  None    None   None  None   None        None  None   None
# 5    spellcheck  None    None   None  None   None        None  None   None
# 6            by  None    None   None  None   None        None  None   None
# 7      harryfan  None    None   None  None   None        None  None   None
# 8            25  None    None   None  None   None        None  None   None
# 9     september  None    None   None  None   None        None  None   None
# 10         2000  None    None   None  None   None        None  None   None
# 11  посвящаться  VERB    None   impf  None   None        None  indc   sing
# 12       любовь  NOUN    anim   None  nomn   femn        None  None   plur
# 13      евгений  NOUN    anim   None  datv   femn        None  None   sing
# 14  белозерский  ADJF    None   None  gent   femn        None  None   sing
# 15        пойти  VERB    None   perf  None   masc        None  indc   sing
# 16       мелкий  ADJF    None   None  nomn   masc        None  None   sing
# 17         снег  NOUN    inan   None  nomn   masc        None  None   sing
# 18            и  CONJ    None   None  None   None        None  None   None
# 19        вдруг  ADVB    None   None  None   None        None  None   None
# 20     повалить  VERB    None   perf  None   masc        None  indc   sing
# 21       хлопья  NOUN    inan   None  ablt   None        None  None   plur
# 22        ветер  NOUN    inan   None  nomn   masc        None  None   sing
# 23       завыть  VERB    None   perf  None   masc        None  indc   sing
# 24    сделаться  VERB    None   perf  None   femn        None  indc   sing
# 25       метель  NOUN    inan   None  nomn   femn        None  None   sing
# 26            в  PREP    None   None  None   None        None  None   None
# 27         один  ADJF    None   None  accs   neut        None  None   sing
# 28    мгновение  NOUN    inan   None  nomn   neut        None  None   sing
# 29       тёмный  ADJF    None   None  nomn   neut        None  None   sing
# 30         небо  NOUN    inan   None  nomn   neut        None  None   sing
# 31    смешаться  VERB    None   perf  None   neut        None  indc   sing
# 32            с  PREP    None   None  None   None        None  None   None
# 33      снежный  ADJF    None   None  datv   None        None  None   plur
# 34         море  NOUN    inan   None  ablt   neut        None  None   sing
# 35         весь  ADJF    None   None  nomn   None        None  None   plur
# 36    исчезнуть  VERB    None   perf  None   neut        None  indc   sing
# 37           ну  PRCL    None   None  None   None        None  None   None
# 38        барин  NOUN    anim   None  nomn   masc        None  None   sing
# 39    закричать  VERB    None   perf  None   masc        None  indc   sing
# 40        ямщик  NOUN    anim   None  nomn   masc        None  None   sing
# 41         беда  NOUN    inan   None  nomn   femn        None  None   sing
# 42        буран  NOUN    inan   None  nomn   masc        None  None   sing
# 43  капитанский  ADJF    None   None  nomn   femn        None  None   sing
# 44        дочка  NOUN    anim   None  nomn   femn        None  None   sing
# 45            и  CONJ    None   None  None   None        None  None   None
# 46       судить  PRTS    None   impf  None   None        None  None   plur
# 47         быть  VERB    None   impf  None   None        None  indc   plur
# 48      мёртвый  NOUN    anim   None  nomn   masc        None  None   plur
# 49           по  PREP    None   None  None   None        None  None   None
#
#    person tense transitivity voice
# 0    None  None         None  None
# 1    None  None         None  None
# 2    None  None         None  None
# 3    None  None         None  None
# 4    None  None         None  None
# 5    None  None         None  None
# 6    None  None         None  None
# 7    None  None         None  None
# 8    None  None         None  None
# 9    None  None         None  None
# 10   None  None         None  None
# 11   3per  pres         intr  None
# 12   None  None         None  None
# 13   None  None         None  None
# 14   None  None         None  None
# 15   None  past         intr  None
# 16   None  None         None  None
# 17   None  None         None  None
# 18   None  None         None  None
# 19   None  None         None  None
# 20   None  past         tran  None
# 21   None  None         None  None
# 22   None  None         None  None
# 23   None  past         intr  None
# 24   None  past         intr  None
# 25   None  None         None  None
# 26   None  None         None  None
# 27   None  None         None  None
# 28   None  None         None  None
# 29   None  None         None  None
# 30   None  None         None  None
# 31   None  past         intr  None
# 32   None  None         None  None
# 33   None  None         None  None
# 34   None  None         None  None
# 35   None  None         None  None
# 36   None  past         intr  None
# 37   None  None         None  None
# 38   None  None         None  None
# 39   None  past         intr  None
# 40   None  None         None  None
# 41   None  None         None  None
# 42   None  None         None  None
# 43   None  None         None  None
# 44   None  None         None  None
# 45   None  None         None  None
# 46   None  pres         None  pssv
# 47   None  past         intr  None
# 48   None  None         None  None
# 49   None  None         None  None

# %% [markdown]
# #### 2. Повторить какие-то из графиков с семинара на своих книжных данных (обязательно - 3 штуки, дальше по желанию)

# %% [markdown]
# ##### 2.1. Вхождение слов по роду

# %%
dataframe['gender'].value_counts().plot.bar(color='purple')
pyplot.title('Gender')
pyplot.xlabel('gender')
pyplot.ylabel('number of entries')
# Out:
# Text(0, 0.5, 'number of entries')

# %% [markdown]
# ##### 2.2. Вхождение слов по роду по частям речи

# %%
import seaborn as sns

dataframe2 = dataframe[
    (dataframe['gender'] != '') & (dataframe['gender'] != 'мж')
][
    ['pos', 'gender', 'number']
].groupby(['pos', 'gender'], as_index=False).count()

dataframe2.columns = ['pos', 'gender', 'total']
sns.barplot(x="POS", y="total", hue='gender', data=dataframe2)
pyplot.title('Gender by POS')
pyplot.xlabel('POS')
pyplot.ylabel('number of entries')
# Out:
# Text(0, 0.5, 'number of entries')

# %% [markdown]
# ##### 2.3. Распределение длины лемм

# %%
dataframe['length'] = dataframe['word'].apply(len)
pyplot.figure(figsize=(10, 6))
sns.distplot(dataframe['length'], bins=20, color='green')
pyplot.title('Distribution of lemma length')
pyplot.ylabel('%')
pyplot.xlabel('Length of word')
# Out:
# Text(0.5, 0, 'Length of word')

# %% [markdown]
# #### 3. Придумать свои визуализации
# ##### 3.1. Облако одушевлённых существительных
# Любопытно было бы посмотреть, какие одушевлённые существительные встречаются чаще:

# %%
from wordcloud import WordCloud

df3 = dataframe[
    (dataframe['pos'] == 'NOUN') & (dataframe['animacy'] == 'anim')
][
    ['word', 'pos', 'animacy']
]

text = ' '.join([word for word in df3['word']])

wordcloud = WordCloud(
    background_color='white',
    width=800,
    height=800,
).generate(text)

pyplot.figure(figsize=(8, 8), facecolor=None)
pyplot.imshow(wordcloud)
pyplot.axis("off")
pyplot.title('Облако слов (включая стоп-слова)')
pyplot.show()

# %% [markdown]
# ##### 3.2. Глаголы по времени
# Идёт ли речь в романе о будущем, или автор концентрирован на описании исключительно прошлого? Может быть, это вселенская катастрофа и потом не будет ничего?

# %%
dataframe4 = dataframe[dataframe['pos'] == 'VERB']

pyplot.figure(figsize=(6, 6))
dataframe4['tense'].value_counts().plot(kind='pie')
pyplot.title('Case')
# Out:
# Text(0.5, 1.0, 'Case')

# %% [markdown]
# #### 4. Освоить nltk dispersion plot и сделать такой график по героям вашей книги
# Возьмём троих основных персонажей, членов семьи Турбиных:

# %%
import nltk
from nltk.draw import dispersion_plot

words = ['алексей', 'елена', 'николка']
text = list(dataframe['word'])

dispersion_plot(text, words)
